# %%
phone_number=674839
print(phone_number)
# Out:
# 674839

# %%
name="sanjib"
print(name)
# Out:
# sanjib

# %%
age=20
height=5.5
name="Sanjib"
is_passed=True
print(type(age),type(height),type(name),type(is_passed))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>
