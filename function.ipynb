# %% [markdown]
# ### Function

# %%
### no parameter no retrun type
def welcome_message():
    print("hello user")

# %%
def welcome_message():
    print("hello user")
welcome_message()

### parameter pass
def welcome_message(user):
    print(f"hello {user}")
welcome_message("phitron")
# Out:
# hello user
# hello phitron

# %%
### return

def add(a,b):
    sum=a+b
    return sum
x=add(10,3)*5
print(x)
# Out:
# 65

# %%
### doc
def add(a,b):

    """
    add two numbers
    """
    sum=a+b
    return sum
x=add(10,3)*5
print(x)
help(add)
# Out:
# 65
# Help on function add in module __main__:
#
# add(a, b)
#     add two numbers

# %%
def func(a,b):  ### parameter
    sum=a+b
    return
func(10,2)     ### arguments

# %% [markdown]
# ### Different types of arguments

# %%
### positional argument
def add(a,b):
    print(f"{a},{b}")
add(10,20)
# Out:
# 10,20

# %%
### Multiple arguments

def add(*args):
    for i in args:
        print(i)
add(10,20,30,40)
# Out:
# 10
# 20
# 30
# 40
