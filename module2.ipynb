# %% [markdown]
# ### Conditional statements in python

# %%
raining=True
if raining==True:
    print("Go with a rain coat")
else:
    print("GO without a rain coat")
# Out:
# Go with a rain coat

# %% [markdown]
# ### Loop statements

# %%
for i in range(10):
    print(i,"hello world")
print(" ")
#range(start,end,step)
for i in range(1,11,2):
    print(i,"hello world")
# Out:
# 0 hello world
# 1 hello world
# 2 hello world
# 3 hello world
# 4 hello world
# 5 hello world
# 6 hello world
# 7 hello world
# 8 hello world
# 9 hello world
#
# 1 hello world
# 3 hello world
# 5 hello world
# 7 hello world
# 9 hello world
